# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
accesso = pd.read_csv(r'c:\Users\andre\Desktop\agent puliyi\Accesso_English.csv')

# %%
# EDA sull'dataset accesso

# Visualizziamo dimensioni, informazioni e valori mancanti
print("Shape:", accesso.shape)
print("\nInfo:")
accesso.info()
print("\nValori mancanti:")
print(accesso.isnull().sum())

# Statistiche descrittive per le variabili numeriche e categoriche
print("\nStatistiche descrittive (numeriche):")
print(accesso.describe())
print("\nStatistiche descrittive (categoriche):")
print(accesso.describe(include=['object']))

# Distribuzioni delle variabili categoriche: gender e region_of_residence
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.countplot(data=accesso, x='gender')
plt.title("Distribuzione di gender")

plt.subplot(1, 2, 2)
sns.countplot(data=accesso, x='region_of_residence')
plt.title("Distribuzione di region_of_residence")
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()
# Out:
# Shape: (8528, 7)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8528 entries, 0 to 8527
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   region_of_residence    8528 non-null   object
#  1   administration         8528 non-null   object
#  2   gender                 8528 non-null   object
#  3   age_max                8528 non-null   int64
#  4   age_min                8528 non-null   int64
#  5   authentication_method  8528 non-null   object
#  6   employee_count         8528 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 466.5+ KB
#
# Valori mancanti:
# region_of_residence      0
# administration           0
# gender                   0
# age_max                  0
# age_min                  0
# authentication_method    0
# employee_count           0
# dtype: int64
#
# Statistiche descrittive (numeriche):
#            age_max      age_min  employee_count
# count  8528.000000  8528.000000     8528.000000
# mean     43.148687    42.994137      177.795145
# std      19.586494    13.882474     1124.427105
# min       0.000000    18.000000        2.000000
# 25%      34.000000    35.000000        3.000000
# 50%      44.000000    45.000000        9.000000
# 75%      54.000000    55.000000       42.000000
# max      64.000000    65.000000    29526.000000
#
# Statistiche descrittive (categoriche):
#        region_of_residence          administration gender  \
# count                 8528                    8528   8528
# unique                  21                      81      2
# top                  LAZIO  MINISTERO DELLA DIFESA      M
# freq                  1256                    1015   4578
#
#        authentication_method
# count                   8528
# unique                     4
# top                     SPID
# freq                    4989

# %%
# Miglioramento dell'EDA sul dataset accesso

# Distribuzione delle variabili numeriche: age_max, age_min, employee_count
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.histplot(accesso['age_max'], kde=True, bins=20, color='blue')
plt.title("Distribuzione di age_max")

plt.subplot(2, 2, 2)
sns.histplot(accesso['age_min'], kde=True, bins=20, color='green')
plt.title("Distribuzione di age_min")

plt.subplot(2, 2, 3)
sns.histplot(accesso['employee_count'], kde=False, bins=20, color='orange')
plt.title("Distribuzione di employee_count")

plt.tight_layout()
plt.show()

# Distribuzione delle variabili categoriche: authentication_method e gender
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.countplot(data=accesso, x='authentication_method', palette='Set2')
plt.title("Distribuzione di authentication_method")
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
sns.countplot(data=accesso, x='gender', palette='Set3')
plt.title("Distribuzione di gender")

plt.tight_layout()
plt.show()

# Distribuzione delle regioni con più occorrenze
plt.figure(figsize=(12, 6))
top_regions = accesso['region_of_residence'].value_counts().head(10)
sns.barplot(x=top_regions.index, y=top_regions.values, palette='viridis')
plt.title("Top 10 regioni per occorrenze")
plt.xticks(rotation=45)
plt.ylabel("Occorrenze")
plt.xlabel("Regione")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_18180\3672959890.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=accesso, x='authentication_method', palette='Set2')
# C:\Users\andre\AppData\Local\Temp\ipykernel_18180\3672959890.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=accesso, x='gender', palette='Set3')
# C:\Users\andre\AppData\Local\Temp\ipykernel_18180\3672959890.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_regions.index, y=top_regions.values, palette='viridis')

# %%
pendolarismo = pd.read_csv(r"C:\Users\andre\Desktop\agent puliyi\Pendolarismo_English.csv")

# %%
# EDA sul dataset "pendolarismo"

# Informazioni di base e statistiche descrittive
print("Shape:", pendolarismo.shape)
print("\nInfo:")
pendolarismo.info()
print("\nValori mancanti:")
print(pendolarismo.isnull().sum())

print("\nStatistiche descrittive (numeriche):")
print(pendolarismo.describe())
print("\nStatistiche descrittive (categoriche):")
print(pendolarismo.describe(include=['object']))

# Analisi grafica delle variabili numeriche
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.histplot(pendolarismo['commuting_distance_min_km'], kde=True, bins=20, color='blue')
plt.title("Distribuzione di commuting_distance_min_km")

plt.subplot(2, 2, 2)
sns.histplot(pendolarismo['commuting_distance_max_km'], kde=True, bins=20, color='green')
plt.title("Distribuzione di commuting_distance_max_km")

plt.subplot(2, 2, 3)
sns.histplot(pendolarismo['average_commuting_distance'], kde=True, bins=20, color='orange')
plt.title("Distribuzione di average_commuting_distance")

plt.subplot(2, 2, 4)
sns.histplot(pendolarismo['employee_count'], kde=False, bins=20, color='red')
plt.title("Distribuzione di employee_count")

plt.tight_layout()
plt.show()

# Analisi delle variabili categoriche: conteggio per organization
plt.figure(figsize=(12, 6))
top_org = pendolarismo['organization'].value_counts().head(10)
sns.barplot(x=top_org.index, y=top_org.values, palette='viridis')
plt.xticks(rotation=45)
plt.title("Top 10 Organizations per numero di occorrenze")
plt.xlabel("Organization")
plt.ylabel("Occorrenze")
plt.tight_layout()
plt.show()
# Out:
# Shape: (24842, 8)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24842 entries, 0 to 24841
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   province_of_office          24842 non-null  object
#  1   office_municipality         24842 non-null  object
#  2   same_municipality           24842 non-null  bool
#  3   organization                24842 non-null  object
#  4   employee_count              24842 non-null  int64
#  5   commuting_distance_min_km   24842 non-null  int64
#  6   commuting_distance_max_km   24842 non-null  int64
#  7   average_commuting_distance  24842 non-null  int64
# dtypes: bool(1), int64(4), object(3)
# memory usage: 1.4+ MB
#
# Valori mancanti:
# province_of_office            0
# office_municipality           0
# same_municipality             0
# organization                  0
# employee_count                0
# commuting_distance_min_km     0
# commuting_distance_max_km     0
# average_commuting_distance    0
# dtype: int64
#
# Statistiche descrittive (numeriche):
#        employee_count  commuting_distance_min_km  commuting_distance_max_km  \
# count    24842.000000               24842.000000               24842.000000
# mean        81.252999                  75.430923                  59.209202
# std        761.856806                 167.676199                 128.988330
# min          6.000000                   0.000000                   0.000000
# 25%         13.000000                   5.000000                   5.000000
# 50%         27.000000                  10.000000                  10.000000
# 75%         57.000000                  50.000000                  50.000000
# max      90451.000000                 600.000000                 600.000000
#
#        average_commuting_distance
# count                24842.000000
# mean                    67.286450
# std                    112.012221
# min                      2.000000
# 25%                      8.000000
# 50%                     15.000000
# 75%                     75.000000
# max                    400.000000
#
# Statistiche descrittive (categoriche):
#        province_of_office office_municipality  \
# count               24842               24842
# unique                108                3026
# top                  ROMA                ROMA
# freq                  972                 410
#
#                                   organization
# count                                    24842
# unique                                      75
# top     MINISTERO DELL'ISTRUZIONE E DEL MERITO
# freq                                     18073
# C:\Users\andre\AppData\Local\Temp\ipykernel_18180\3117023550.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_org.index, y=top_org.values, palette='viridis')

# %%
reddito = pd.read_csv(r"C:\Users\andre\Desktop\agent puliyi\Reddito_English.csv")

# %%
# EDA sul dataset "reddito"

# Informazioni di base e statistiche descrittive
print("Shape:", reddito.shape)
print("\nInfo:")
reddito.info()
print("\nValori mancanti:")
print(reddito.isnull().sum())

print("\nStatistiche descrittive (numeriche):")
print(reddito.describe())
print("\nStatistiche descrittive (categoriche):")
print(reddito.describe(include=['object']))

# Analisi grafica delle variabili numeriche
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.histplot(reddito['age_min'], kde=True, bins=20, color='blue')
plt.title("Distribuzione di age_min")

plt.subplot(2, 2, 2)
sns.histplot(reddito['age_max'].dropna(), kde=True, bins=20, color='green')
plt.title("Distribuzione di age_max")

plt.subplot(2, 2, 3)
sns.histplot(reddito['income_bracket_min'], kde=True, bins=20, color='orange')
plt.title("Distribuzione di income_bracket_min")

plt.subplot(2, 2, 4)
sns.histplot(reddito['income_bracket_max'].dropna(), kde=True, bins=20, color='red')
plt.title("Distribuzione di income_bracket_max")

plt.tight_layout()
plt.show()

# Analisi delle variabili categoriche
plt.figure(figsize=(15, 10))

plt.subplot(2, 1, 1)
sns.countplot(data=reddito, x='gender', palette='Set2')
plt.title("Distribuzione di gender")

plt.subplot(2, 1, 2)
top_sectors = reddito['sector'].value_counts().head(10)
sns.barplot(x=top_sectors.index, y=top_sectors.values, palette='viridis')
plt.title("Top 10 settori per occorrenze")
plt.xticks(rotation=45)
plt.ylabel("Occorrenze")
plt.xlabel("Settore")

plt.tight_layout()
plt.show()

# Analisi delle regioni con più occorrenze
plt.figure(figsize=(12, 6))
top_regions_reddito = reddito['region_of_residence'].value_counts().head(10)
sns.barplot(x=top_regions_reddito.index, y=top_regions_reddito.values, palette='viridis')
plt.title("Top 10 regioni per occorrenze")
plt.xticks(rotation=45)
plt.ylabel("Occorrenze")
plt.xlabel("Regione")

plt.tight_layout()
plt.show()
# Out:
# Shape: (5099, 9)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5099 entries, 0 to 5098
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   sector               5099 non-null   object
#  1   region_of_residence  5099 non-null   object
#  2   gender               5099 non-null   object
#  3   age_min              5099 non-null   int64
#  4   age_max              4299 non-null   float64
#  5   max_tax_rate         5099 non-null   int64
#  6   income_bracket_min   5099 non-null   int64
#  7   income_bracket_max   3376 non-null   float64
#  8   employee_count       5099 non-null   int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 358.7+ KB
#
# Valori mancanti:
# sector                    0
# region_of_residence       0
# gender                    0
# age_min                   0
# age_max                 800
# max_tax_rate              0
# income_bracket_min        0
# income_bracket_max     1723
# employee_count            0
# dtype: int64
#
# Statistiche descrittive (numeriche):
#            age_min      age_max  max_tax_rate  income_bracket_min  \
# count  5099.000000  4299.000000   5099.000000         5099.000000
# mean     44.505785    49.552454     33.871936        26494.214552
# std      13.863048    11.914881      8.145106        20289.792327
# min      18.000000    24.000000     23.000000            0.000000
# 25%      35.000000    44.000000     23.000000            0.000000
# 50%      45.000000    54.000000     35.000000        28000.000000
# 75%      55.000000    64.000000     43.000000        50000.000000
# max      65.000000    64.000000     43.000000        50000.000000
#
#        income_bracket_max  employee_count
# count         3376.000000     5099.000000
# mean         39390.995261      377.161208
# std          10994.677315     1754.198115
# min          28000.000000        1.000000
# 25%          28000.000000        2.000000
# 50%          50000.000000        6.000000
# 75%          50000.000000       58.000000
# max          50000.000000    28376.000000
#
# Statistiche descrittive (categoriche):
#                             sector region_of_residence gender
# count                         5099                5099   5099
# unique                          22                  21      2
# top     COMPARTO FUNZIONI CENTRALI               LAZIO      M
# freq                           594                 515   2650
# C:\Users\andre\AppData\Local\Temp\ipykernel_18180\3003054278.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=reddito, x='gender', palette='Set2')
# C:\Users\andre\AppData\Local\Temp\ipykernel_18180\3003054278.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_sectors.index, y=top_sectors.values, palette='viridis')
# C:\Users\andre\AppData\Local\Temp\ipykernel_18180\3003054278.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_regions_reddito.index, y=top_regions_reddito.values, palette='viridis')

# %%
stipendi = pd.read_csv(r"C:\Users\andre\Desktop\agent puliyi\Stipendi_English.csv")

# %%
# EDA sul dataset "stipendi"

# Informazioni di base
print("Shape:", stipendi.shape)
print("\nInfo:")
stipendi.info()
print("\nValori mancanti:")
print(stipendi.isnull().sum())

print("\nStatistiche descrittive (numeriche):")
print(stipendi.describe())

print("\nStatistiche descrittive (categoriche):")
print(stipendi.describe(include=['object']))

# Visualizzazione grafica
plt.figure(figsize=(15, 10))

# Distribuzione di age_min
plt.subplot(2, 2, 1)
sns.histplot(stipendi['age_min'], kde=True, bins=20, color='blue')
plt.title("Distribuzione di age_min")

# Distribuzione di age_max
plt.subplot(2, 2, 2)
sns.histplot(stipendi['age_max'], kde=True, bins=20, color='green')
plt.title("Distribuzione di age_max")

# Distribuzione di gender
plt.subplot(2, 2, 3)
sns.countplot(data=stipendi, x='gender', palette='Set2')
plt.title("Distribuzione di gender")

# Distribuzione di payment_method
plt.subplot(2, 2, 4)
sns.countplot(data=stipendi, x='payment_method', palette='Set3')
plt.title("Distribuzione di payment_method")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# Analisi della distribuzione di salary_count
plt.figure(figsize=(10, 6))
sns.histplot(stipendi['salary_count'], kde=False, bins=20, color='purple')
plt.title("Distribuzione di salary_count")
plt.xlabel("Salary Count")
plt.ylabel("Frequenza")
plt.show()
# Out:
# Shape: (25580, 7)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25580 entries, 0 to 25579
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   office_municipality  25580 non-null  object
#  1   administration       25580 non-null  object
#  2   age_min              25580 non-null  int64
#  3   age_max              25580 non-null  int64
#  4   gender               25580 non-null  object
#  5   payment_method       25580 non-null  object
#  6   salary_count         25580 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 1.4+ MB
#
# Valori mancanti:
# office_municipality    0
# administration         0
# age_min                0
# age_max                0
# gender                 0
# payment_method         0
# salary_count           0
# dtype: int64
#
# Statistiche descrittive (numeriche):
#             age_min       age_max  salary_count
# count  25580.000000  25580.000000  25580.000000
# mean      43.136083     45.644644     71.069273
# std       12.787181     17.864739    595.019641
# min       18.000000      0.000000      6.000000
# 25%       35.000000     34.000000     11.000000
# 50%       45.000000     54.000000     25.000000
# 75%       55.000000     64.000000     52.000000
# max       65.000000     64.000000  58874.000000
#
# Statistiche descrittive (categoriche):
#        office_municipality                          administration gender  \
# count                25580                                   25580  25580
# unique                2891                                      63      2
# top                   ROMA  MINISTERO DELL'ISTRUZIONE E DEL MERITO      F
# freq                   430                                   19255  15802
#
#                     payment_method
# count                        25580
# unique                           3
# top     Conto corrente/Carta conto
# freq                         25104
# C:\Users\andre\AppData\Local\Temp\ipykernel_18180\1541603642.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=stipendi, x='gender', palette='Set2')
# C:\Users\andre\AppData\Local\Temp\ipykernel_18180\1541603642.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=stipendi, x='payment_method', palette='Set3')

# %%
# accesso:
# • La distribuzione delle età (age_min e age_max) si presenta relativamente simmetrica, 
#   suggerendo una copertura omogenea delle fasce d'età. Tuttavia, occorre verificare ulteriormente
#   se esistono outlier nelle estremità che potrebbero influenzare successivi modelli analitici.
# • La distribuzione di 'employee_count' varia notevolmente, indicando che alcune amministrazioni  
#   gestiscono strutture molto più grandi rispetto ad altre.
# • Le modalità di autenticazione (SPID vs. CIE) evidenziano una predominanza di SPID, anche se
#   casi isolati di altre metodologie potrebbero indicare processi particolari di autenticazione.

# pendolarismo:
# • Le distribuzioni delle variabili relative alle distanze (commuting_distance_min_km, commuting_distance_max_km, e average_commuting_distance)
#   mostrano una forte dispersione. La presenza di valori molto alti, ad esempio, in commuting_distance_max_km,
#   potrebbe indicare outlier o percorsi eccezionalmente lunghi.
# • Il forte picco nel conteggio di 'employee_count' per alcune organizzazioni (come MINISTERO DELL'ISTRUZIONE E DEL MERITO)
#   suggerisce che, per tali istituzioni, l'effetto pendolarismo è particolarmente significativo.

# reddito:
# • La distribuzione delle età evidenzia un clustering nei gruppi più centrali mentre, in alcuni casi,
#   la presenza di valori mancanti in age_max e income_bracket_max impone una gestione accurata di queste variabili.
# • Le distribuzioni degli income_bracket indicano che la maggior parte dei redditi rientra in fasce basse,
#   corroborando l'idea di una concentrazione in valori attorno a soglie fisse (ad es. reddito fino a 28000€).
# • L'analisi per 'sector' e 'gender' mostra potenziali disparità nei settori e nelle distribuzioni di genere,
#   evidenziando possibili pattern legati a ruoli specifici in alcuni ambiti lavorativi.
# • Le regioni come LAZIO e CAMPANIA risultano predominanti, il che potrebbe derivare da una maggiore centralizzazione dei servizi
#   o da una demografia più consistente in queste aree.

# stipendi:
# • Le distribuzioni per age_min e age_max evidenziano gruppi consistenti nelle fasce d'età, indicando una certa standardizzazione 
#   nelle politiche retributive per età.
# • La predominanza del payment_method "Conto corrente/Carta conto" suggerisce una forte standardizzazione nei sistemi di pagamento,
#   mentre eventuali anomalie in altri metodi potrebbero essere da approfondire.
# • La variabilità nella distribuzione di salary_count lascia intuire che il numero di pagamenti (o la frequenza degli stessi)
#   varia significativamente tra le amministrazioni, potenzialmente influenzata da differenze organizzative e contratto lavorativo.
